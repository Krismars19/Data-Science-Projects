# %% [markdown]
# ### Building a Chatbot

# %% [markdown]
# Install libraries

# %%
# !pip install Keras
# Out:
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras) (1.15.0)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('intents.json').read()
intents = json.loads(intents_file)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ###### Tokenizing

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
  for pattern in intent['patterns']:
      # Tokenize each word
      word = nltk.word_tokenize(pattern)
      words.extend(word)        
      # Add documents in the corpus
      documents.append((word, intent['tag']))
      # Add to our classes list
      if intent['tag'] not in classes:
        classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %% [markdown]
# #### Lemmatization

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ###### Create Training and Testing Data

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
  # initializing bag of words
  bag = []
  # list of tokenized words for the pattern
  word_patterns = doc[0]
  # lemmatize each word - create base word, in attempt to represent related words
  word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
  # create the bag of words array with 1, if word is found in current pattern
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)
    
  # output is a '0' for each tag and '1' for current tag (for each pattern)
  output_row = list(output_empty)
  output_row[classes.index(doc[1])] = 1
  training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created

# %% [markdown]
# ###### Training the Model

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.2628 - accuracy: 0.1064
# Epoch 2/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1552 - accuracy: 0.1489
# Epoch 3/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.0347 - accuracy: 0.2979
# Epoch 4/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9273 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8804 - accuracy: 0.3191
# Epoch 6/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8418 - accuracy: 0.2979
# Epoch 7/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5786 - accuracy: 0.6383
# Epoch 8/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4754 - accuracy: 0.5957
# Epoch 9/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4019 - accuracy: 0.5532
# Epoch 10/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2159 - accuracy: 0.6596
# Epoch 11/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0843 - accuracy: 0.6383
# Epoch 12/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9871 - accuracy: 0.7872
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8862 - accuracy: 0.7660
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8190 - accuracy: 0.7021
# Epoch 15/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7967 - accuracy: 0.7447
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7052 - accuracy: 0.8298
# Epoch 17/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5420 - accuracy: 0.9149
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4116 - accuracy: 0.9362
# Epoch 19/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5755 - accuracy: 0.8298
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.9149
# Epoch 21/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4810 - accuracy: 0.8723
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.8723
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4866 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3218 - accuracy: 0.9149
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.9362
# Epoch 26/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2671 - accuracy: 0.9574
# Epoch 27/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9362
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9149
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9787
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2246 - accuracy: 0.9362
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2009 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2805 - accuracy: 0.9149
# Epoch 34/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2913 - accuracy: 0.8936
# Epoch 35/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1756 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2335 - accuracy: 0.8936
# Epoch 38/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2679 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.9149
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9574
# Epoch 45/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1376 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1238 - accuracy: 0.9362
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9149
# Epoch 49/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1266 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0721 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0857 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1140 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0676 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9574
# Epoch 72/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1283 - accuracy: 0.9362
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0635 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0708 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0601 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0749 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0685 - accuracy: 0.9574
# Epoch 111/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9787
# Epoch 128/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9787
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9787
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0386 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9787
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9787
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9787
# model is created
